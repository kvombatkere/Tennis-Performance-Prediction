# %% [markdown]
# ### Karan Vombatkere
# CSC 440: Data Mining - Final Project
#
# Below is an implementation of Python code on a dataset with detailed tennis match information from the ATP World Tour.
# This notebook contains scripts that import, clean and process the match data to extract the required features to be used in the ML models. The pandas library was used extensively to store, clean and process the data.
#
# First unique tennis player information was extracted into a Pandas dataframe. The following attributes were extracted from the match data - 'PlayerID', 'PName', 'Age', 'Height', 'MaxRank', 'Hand', 'Country'
#
# Then a function computePlayerStats() was written to calculate the following cumulative (average) statistics of a players: 'PlayerID', 'PName', 'Height(cm)', 'Matches Played', 'Overall Win%', 'Top 100 Win %', 'Top 30 Win %', 'First Serve %', 'First Serve Win %', 'BPSave %', 'BPConv %', 'Aces/Match', 'DF/Match', 'Future Top 30'
#
# The required features were extracted for valid players (having played ~50 matches under the age of 26) and these tuples were returned as a new dataframe. Finally, this dataframe was exported as a .csv file, to be used as training and test data for the Machine Learning models (Logistic Regression and Neural Network).

# %%
#Karan Vombatkere
#CSC 440: Data Mining Final Project
#November - Decemeber 2017

#Imports needed
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import time

import itertools as itools
from statistics import *

# %%
#Load ATPTennis.csv Dataset into a dataframe

ATPData = pd.read_csv("atp_matches_combined.csv", error_bad_lines=False)
ATPData.name = "ATP Match Data"
# Out:
# b'Skipping line 50181: expected 49 fields, saw 69\nSkipping line 50182: expected 49 fields, saw 69\nSkipping line 50183: expected 49 fields, saw 69\nSkipping line 50184: expected 49 fields, saw 69\nSkipping line 50185: expected 49 fields, saw 69\nSkipping line 50186: expected 49 fields, saw 69\nSkipping line 50187: expected 49 fields, saw 69\nSkipping line 50188: expected 49 fields, saw 69\nSkipping line 50189: expected 49 fields, saw 69\nSkipping line 50190: expected 49 fields, saw 69\nSkipping line 50191: expected 49 fields, saw 69\nSkipping line 50192: expected 49 fields, saw 69\nSkipping line 50193: expected 49 fields, saw 69\nSkipping line 50194: expected 49 fields, saw 69\nSkipping line 50195: expected 49 fields, saw 69\nSkipping line 50196: expected 49 fields, saw 69\nSkipping line 50197: expected 49 fields, saw 69\nSkipping line 50198: expected 49 fields, saw 69\nSkipping line 50199: expected 49 fields, saw 69\nSkipping line 50200: expected 49 fields, saw 69\nSkipping line 50201: expected 49 fields, saw 69\nSkipping line 50202: expected 49 fields, saw 69\nSkipping line 50203: expected 49 fields, saw 69\nSkipping line 50204: expected 49 fields, saw 69\nSkipping line 50205: expected 49 fields, saw 69\nSkipping line 50206: expected 49 fields, saw 69\nSkipping line 50207: expected 49 fields, saw 69\nSkipping line 50208: expected 49 fields, saw 69\nSkipping line 50209: expected 49 fields, saw 69\nSkipping line 50210: expected 49 fields, saw 69\nSkipping line 50211: expected 49 fields, saw 69\nSkipping line 50212: expected 49 fields, saw 69\nSkipping line 50213: expected 49 fields, saw 69\nSkipping line 50214: expected 49 fields, saw 69\nSkipping line 50215: expected 49 fields, saw 69\nSkipping line 50216: expected 49 fields, saw 69\nSkipping line 50217: expected 49 fields, saw 69\nSkipping line 50218: expected 49 fields, saw 69\nSkipping line 50219: expected 49 fields, saw 69\nSkipping line 50220: expected 49 fields, saw 69\nSkipping line 50221: expected 49 fields, saw 69\nSkipping line 50222: expected 49 fields, saw 69\nSkipping line 50223: expected 49 fields, saw 69\nSkipping line 50224: expected 49 fields, saw 69\nSkipping line 50225: expected 49 fields, saw 69\nSkipping line 50226: expected 49 fields, saw 69\nSkipping line 50227: expected 49 fields, saw 69\nSkipping line 50228: expected 49 fields, saw 69\nSkipping line 50229: expected 49 fields, saw 69\nSkipping line 50230: expected 49 fields, saw 69\nSkipping line 50231: expected 49 fields, saw 69\nSkipping line 50232: expected 49 fields, saw 69\nSkipping line 50233: expected 49 fields, saw 69\nSkipping line 50234: expected 49 fields, saw 69\nSkipping line 50235: expected 49 fields, saw 69\nSkipping line 50236: expected 49 fields, saw 69\nSkipping line 50237: expected 49 fields, saw 69\nSkipping line 50238: expected 49 fields, saw 69\nSkipping line 50239: expected 49 fields, saw 69\nSkipping line 50240: expected 49 fields, saw 69\nSkipping line 50241: expected 49 fields, saw 69\nSkipping line 50242: expected 49 fields, saw 69\nSkipping line 50243: expected 49 fields, saw 69\nSkipping line 50244: expected 49 fields, saw 69\nSkipping line 50245: expected 49 fields, saw 69\nSkipping line 50246: expected 49 fields, saw 69\nSkipping line 50247: expected 49 fields, saw 69\nSkipping line 50248: expected 49 fields, saw 69\nSkipping line 50249: expected 49 fields, saw 69\nSkipping line 50250: expected 49 fields, saw 69\nSkipping line 50251: expected 49 fields, saw 69\nSkipping line 50252: expected 49 fields, saw 69\nSkipping line 50253: expected 49 fields, saw 69\nSkipping line 50254: expected 49 fields, saw 69\nSkipping line 50255: expected 49 fields, saw 69\nSkipping line 50256: expected 49 fields, saw 69\nSkipping line 50257: expected 49 fields, saw 69\nSkipping line 50258: expected 49 fields, saw 69\nSkipping line 50259: expected 49 fields, saw 69\nSkipping line 50260: expected 49 fields, saw 69\nSkipping line 50261: expected 49 fields, saw 69\nSkipping line 50262: expected ...

# %%
#View the data
ATPData.head(10)
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0   2000-717      Orlando    Clay       32.0             A    20000501.0
# 1   2000-717      Orlando    Clay       32.0             A    20000501.0
# 2   2000-717      Orlando    Clay       32.0             A    20000501.0
# 3   2000-717      Orlando    Clay       32.0             A    20000501.0
# 4   2000-717      Orlando    Clay       32.0             A    20000501.0
# 5   2000-717      Orlando    Clay       32.0             A    20000501.0
# 6   2000-717      Orlando    Clay       32.0             A    20000501.0
# 7   2000-717      Orlando    Clay       32.0             A    20000501.0
# 8   2000-717      Orlando    Clay       32.0             A    20000501.0
# 9   2000-717      Orlando    Clay       32.0             A    20000501.0
#
#    match_num  winner_id  winner_seed winner_entry    ...    w_bpFaced l_ace  \
# 0        1.0   102179.0          NaN          NaN    ...         15.0  13.0
# 1        2.0   103602.0          NaN            Q    ...          6.0   0.0
# 2        3.0   103387.0          NaN          NaN    ...          0.0   2.0
# 3        4.0   101733.0          NaN          NaN    ...         12.0   4.0
# 4        5.0   101727.0          4.0          NaN    ...          1.0   0.0
# 5        6.0   103181.0          NaN          NaN    ...          6.0  11.0
# 6        7.0   101675.0          NaN          NaN    ...         12.0   5.0
# 7        8.0   102834.0          5.0          NaN    ...          0.0   0.0
# 8        9.0   103454.0          6.0          NaN    ...          4.0   2.0
# 9       10.0   102466.0          NaN          NaN    ...          6.0   3.0
#
#    l_df l_svpt  l_1stIn  l_1stWon  l_2ndWon  l_SvGms  l_bpSaved l_bpFaced
# 0   4.0  110.0     59.0      49.0      31.0     17.0        4.0       4.0
# 1   0.0   57.0     24.0      13.0      17.0     10.0        4.0       9.0
# 2   2.0   65.0     39.0      22.0      10.0      8.0        6.0      10.0
# 3   6.0  104.0     57.0      35.0      24.0     15.0        6.0      11.0
# 4   3.0   47.0     28.0      17.0      10.0      8.0        3.0       6.0
# 5   8.0   94.0     48.0      31.0      29.0     15.0        6.0       9.0
# 6   5.0  126.0     70.0      45.0      36.0     18.0        3.0       6.0
# 7   0.0   42.0     25.0       9.0      10.0      7.0        3.0       7.0
# 8   3.0   47.0     25.0      13.0      10.0      8.0        3.0       7.0
# 9   2.0  102.0     62.0      43.0      14.0     14.0        9.0      13.0
#
# [10 rows x 49 columns]

# %%
#Create dataframe for Player Data and label columns
PlayerColumns = ['PlayerID', 'PName', 'Age', 'Height', 'MaxRank', 'Hand', 'Country']

PlayerData = pd.DataFrame(columns = PlayerColumns)
PlayerData.set_index('PlayerID')


#Add data to the PlayerData dataframe
for index, row in ATPData.head(50180).iterrows():
    #If player was the winner
    p_id = int(row.winner_id)
    
    #Check if value exists or not
    if(p_id not in PlayerData.index):
        PlayerData.loc[p_id] = [p_id, row.winner_name, row.winner_age, row.winner_ht, row.winner_rank, row.winner_hand, row.winner_ioc]

    #Update rank with best rank value
    if(row.winner_rank < PlayerData.loc[p_id].MaxRank and not np.isnan(PlayerData.loc[p_id].MaxRank)):
        PlayerData.loc[p_id] = [p_id, row.winner_name, row.winner_age, row.winner_ht, row.winner_rank, row.winner_hand, row.winner_ioc]
    
    else:
        PlayerData.loc[p_id] = [p_id, row.winner_name, row.winner_age, row.winner_ht, PlayerData.loc[p_id].MaxRank, row.winner_hand, row.winner_ioc]
   

    #If the player lost
    p_id2 = int(row.loser_id)
    
    #Check if value exists or not
    if(p_id2 not in PlayerData.index):
        PlayerData.loc[p_id2] = [p_id2, row.loser_name, row.loser_age, row.loser_ht, row.loser_rank, row.loser_hand, row.loser_ioc]

    if(row.loser_rank < PlayerData.loc[p_id2].MaxRank and not np.isnan(PlayerData.loc[p_id2].MaxRank)):
        PlayerData.loc[p_id2] = [p_id2, row.loser_name, row.loser_age, row.loser_ht, row.loser_rank, row.loser_hand, row.loser_ioc]

    else:
        PlayerData.loc[p_id2] = [p_id2, row.loser_name, row.loser_age, row.loser_ht, PlayerData.loc[p_id2].MaxRank, row.loser_hand, row.loser_ioc]

# %%
#View the Player Data
PlayerData.head(100)
# Out:
#        PlayerID                PName        Age  Height  MaxRank Hand Country
# 102179   102179        Antony Dupuis  34.368241   185.0     57.0    R     FRA
# 102776   102776          Andrew Ilie  26.737851   180.0     38.0    R     AUS
# 103602   103602    Fernando Gonzalez  31.561944   183.0      5.0    R     CHI
# 102735   102735     Cedric Kauffmann  25.240246     NaN    250.0    R     FRA
# 103894   103894         Phillip King  32.336756   175.0    300.0    R     USA
# 102839   102839     Nicolas Lapentti  33.546886   188.0      6.0    R     ECU
# 103184   103184            Bob Bryan  31.186858   193.0    126.0    L     USA
# 103720   103720       Lleyton Hewitt  34.379192   180.0      1.0    R     AUS
# 103714   103714  Andreas Vinciguerra  32.380561   180.0     33.0    L     SWE
# 102369   102369       Julien Boutter  30.212183   190.0     46.0    R     FRA
# 101647   101647          Byron Black  32.944559   175.0     27.0    R     ZIM
# 103758   103758          Taylor Dent  28.832307   188.0     21.0    R     USA
# 102701   102701         Marcelo Rios  27.529090   175.0      7.0    L     CHI
# 102533   102533     Jens Knippschild  27.277207   190.0     85.0    R     GER
# 102443   102443          Barry Cowan  27.830253   188.0    163.0    L     GBR
# 102770   102770      John Van Lottum  29.883641   185.0     66.0    R     NED
# 103264   103264       Mariano Puerta  27.000684   180.0      9.0    L     ARG
#
# [100 rows x 7 columns]

# %%
PlayerData.loc[103819]
# Out:
# PlayerID           103819
# PName       Roger Federer
# Age               34.0999
# Height                185
# MaxRank                 1
# Hand                    R
# Country               SUI
# Name: 103819, dtype: object

# %%
ATPData.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'winner_rank', 'winner_rank_points', 'loser_id', 'loser_seed',
#        'loser_entry', 'loser_name', 'loser_hand', 'loser_ht', 'loser_ioc',
#        'loser_age', 'loser_rank', 'loser_rank_points', 'score', 'best_of',
#        'round', 'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon',
#        'w_2ndWon', 'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df',
#        'l_svpt', 'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved',
#        'l_bpFaced'],
#       dtype='object')

# %%
#Create Data Frame for calculating Player Statistics
#Specify Column Names
PlayerStatsColumns = ['PlayerID', 'PName', 'Height(cm)', 'Matches Played', 'Overall Win%', 'Top 100 Win %', 'Top 30 Win %', 'First Serve %', 'First Serve Win %', 'BPSave %', 'BPConv %', 'Aces/Match', 'DF/Match', 'Future Top 30']

PlayerStats = pd.DataFrame(index = PlayerData.index.copy(), columns = PlayerStatsColumns)

# %%
#Function to compute statistics and Populate the PlayerStats Table
#Note that we reject all tuples that have invalid/incomplete statistics data

#Inputs: 
#playerCount = number of players to calculate data for
#matchRows = number of rows of match data to consider
#initMatches = initial number of matches played to calculate features

#Output: Updates the Player Stats table dynamicall using loc pandas function

def computePlayerStats(playerCount, matchRows, initMatches):
    playerAge = 27 #Age of player to be considered for initial matches
    
    start = time.time() #compute the start time
    validPlayers = 0 #valid player/data count
    
    #Iterate over each player
    for p_indx, player in PlayerData.head(playerCount).iterrows(): #Search stats for each player in PlayerData Table

        #Initialize cumulative stat data for each player for a particular year
        FirstServe = 0
        FirstServeWin = 0
        FirstServeCounter = 0

        BPSaved = 0
        BPFaced = 0

        BPChances = 0
        BPWon = 0

        Aces = 0
        DF = 0
        numMatches = 0
        Wins = 0

        top30 = False #Boolean to keep track if the player ever breaks into the top 30
        #This is computationally expensive since we must check every match
        
        #Keep track of win record against top 30 opponents
        top30matches = 0
        top30wins = 0
        
        #Keep track of win record against top 100 opponents
        top100matches = 0
        top100wins = 0

        #Iterate over the match data for each player
        for index, row in ATPData.head(matchRows).iterrows():

            #If player won the match and is under age playerAge
            if(p_indx == row.winner_id and row.winner_age < playerAge):
                #Only compute statistics for first 50 matches of the player
                if(numMatches < initMatches):
                    
                    #if(p_indx == 103819): #Federer matches check!
                        #print(player.PName, row.score, row.loser_name)
                        #print(row.WAces, row.WDF, FirstServe, BPSaved, BPFaced)
                        #print(index)
                        
                    #Check whether or not the match was a walkover and has valid stats
                    if(not np.isnan(row.w_ace) and not np.isnan(row.w_df) and not np.isnan(row.w_svpt) and not np.isnan(row.w_bpFaced) and not np.isnan(row.w_bpSaved) and row.w_svpt != 0):
                        Aces += row.w_ace
                        DF += row.w_df
                        FirstServe += (row.w_1stIn / row.w_svpt) #calculate first serve percentage
                        FirstServeWin += (row.w_1stWon/ row.w_1stIn) #calculate first serve win rate
                        FirstServeCounter += 1

                        BPSaved += row.w_bpSaved
                        BPFaced += row.w_bpFaced

                        BPChances += row.l_bpFaced
                        BPWon += (row.l_bpFaced - row.l_bpSaved)
                        numMatches += 1
                        Wins += 1
                        
                        #Increment top30 wins if player beat a top 30 opponent
                        if(row.loser_rank <= 30):
                            top30wins += 1
                            top30matches += 1
                            
                        #Increment top100 wins if player beat a top 100 opponent
                        if(row.loser_rank <= 100):
                            top100wins += 1
                            top100matches += 1
                            
                #Break out of loop once first 50 matches have been calculated           
                else:
                    break

            #If player lost the match and is under age 26
            if(p_indx == row.loser_id and row.loser_age < playerAge):
                #Only compute statistics for first 50 matches of the player
                if(numMatches < initMatches):
                    
                    #if(p_indx == 103819):
                        #print(row.winner_name, row.score, player.PName)
                        #print(Aces, DF, FirstServe, BPSaved, BPFaced)

                        
                    #Check whether or not the match was a walkover and has valid stats
                    if(not np.isnan(row.l_ace) and not np.isnan(row.l_df) and not np.isnan(row.l_svpt) and not np.isnan(row.l_bpFaced) and not np.isnan(row.l_bpSaved) and row.l_svpt != 0):
                        Aces += row.l_ace
                        DF += row.l_df
                        FirstServe += (row.l_1stIn / row.l_svpt) #calculate first serve percentage
                        FirstServeWin += (row.l_1stWon/ row.l_1stIn) #calculate first serve win rate
                        FirstServeCounter += 1

                        BPSaved += row.l_bpSaved
                        BPFaced += row.l_bpFaced

                        BPChances += row.w_bpFaced
                        BPWon += (row.w_bpFaced - row.w_bpSaved)
                        numMatches += 1
                        
                        #Increment top30 matches if player lost to a top 30 opponent
                        if(row.winner_rank <= 30):
                            top30matches += 1
                        
                        #Increment top100 matches if player lost to a top 100 opponent
                        if(row.winner_rank <= 100):
                            top100matches += 1
                    
                #Break out of loop once first 50 matches have been calculated           
                else:
                    break

        
        #Update the cumulative statistics for the Player
        winPercent = 0
        servePercentage = 0
        firstservewinRate = 0
        BPsaveRate = 0
        BPconvRate = 0
        
        top30winPercent = 0
        top100winPercent = 0
        
        #Mark true if the player ever broke into the top 30 in the dataset
        if(player.MaxRank <= 30):
            top30 = True

        #Calculate first serve percentage, win percentage and BP percentages
        if(numMatches != 0 and FirstServeCounter != 0):
            winPercent = Wins/numMatches
            #compute aces and double faults per match
            Aces = Aces/numMatches
            DF = DF/numMatches
            
            servePercentage = FirstServe/FirstServeCounter #average first serve percentage
            firstservewinRate = FirstServeWin/FirstServeCounter #average first serve win rate

            if(BPFaced != 0 and BPChances != 0):
                BPsaveRate = BPSaved/BPFaced
                BPconvRate = BPWon/BPChances
            
            if(top30matches != 0):
                top30winPercent = top30wins/top30matches
                top100winPercent = top100wins/top100matches
                
            
            #Check if this is a valid entry that the player has played initMatches matches below age 26
            if(numMatches == initMatches):
                validPlayers += 1
                
                #Add the cumulative statistics to the database
                print("Updating Cumulative Player Statistics for Player:", player.PName)
                PlayerStats.loc[p_indx] = [p_indx, player.PName, player.Height, numMatches, winPercent, top100winPercent, top30winPercent, servePercentage, firstservewinRate, BPsaveRate, BPconvRate, Aces, DF, top30]
    
    
    #compute runtime
    end = time.time()
    runTime = end - start
    
    print("Player Statistics Generation Runtime =", runTime, 'seconds')
    print("Number of valid players with", initMatches, "matches of initial match data =", validPlayers)
    
    #Drop all rows that have invalid statistics (insufficient matches, stats etc) and return final feature set
    #Copy the valid data with final extracted features to dataframe to be returned
    extractedFeatures = PlayerStats.dropna() 
    
    #Return the cleaned and processed player information
    return extractedFeatures

# %%
#Run the statistic generator function
#Specify inputs (total players = 1981, totalRows = 50180) -> Takes about 2.5 hours to run

numPlayers = 1981
numRows = 50180
initMatches = 40

#Call the statistic generator with inputs specified
ATPplayerFeatures = computePlayerStats(numPlayers, numRows, initMatches)
# Out:
# Updating Cumulative Player Statistics for Player: Andrew Ilie
# Updating Cumulative Player Statistics for Player: Fernando Gonzalez
# Updating Cumulative Player Statistics for Player: Cecil Mamiit
# Updating Cumulative Player Statistics for Player: Paradorn Srichaphan
# Updating Cumulative Player Statistics for Player: Justin Gimelstob
# Updating Cumulative Player Statistics for Player: Jiri Vanek
# Updating Cumulative Player Statistics for Player: Paul Goldstein
# Updating Cumulative Player Statistics for Player: Nicolas Massu
# Updating Cumulative Player Statistics for Player: Michael Russell
# Updating Cumulative Player Statistics for Player: Alexander Popp
# Updating Cumulative Player Statistics for Player: Andre Sa
# Updating Cumulative Player Statistics for Player: Markus Hantschk
# Updating Cumulative Player Statistics for Player: Xavier Malisse
# Updating Cumulative Player Statistics for Player: Ramon Delgado
# Updating Cumulative Player Statistics for Player: Jan Michael Gambill
# Updating Cumulative Player Statistics for Player: Michal Tabara
# Updating Cumulative Player Statistics for Player: Andrei Stoliarov
# Updating Cumulative Player Statistics for Player: Kevin Kim
# Updating Cumulative Player Statistics for Player: Stefan Koubek
# Updating Cumulative Player Statistics for Player: Yevgeny Kafelnikov
# Updating Cumulative Player Statistics for Player: Andrei Medvedev
# Updating Cumulative Player Statistics for Player: Mardy Fish
# Updating Cumulative Player Statistics for Player: Galo Blanco
# Updating Cumulative Player Statistics for Player: George Bastl
# Updating Cumulative Player Statistics for Player: Gustavo Kuerten
# Updating Cumulative Player Statistics for Player: Vladimir Voltchkov
# Updating Cumulative Player Statistics for Player: Felix Mantilla
# Updating Cumulative Player Statistics for Player: James Blake
# Updating Cumulative Player Statistics for Player: Nicolas Escude
# Updating Cumulative Player Statistics for Player: Kristian Pless
# Updating Cumulative Player Statistics for Player: Jacobo Diaz
# Updating Cumulative Player Statistics for Player: Mikhail Youzhny
# Updating Cumulative Player Statistics for Player: Raemon Sluiter
# Updating Cumulative Player Statistics for Player: Noam Okun
# Updating Cumulative Player Statistics for Player: Michael Llodra
# Updating Cumulative Player Statistics for Player: Guillermo Canas
# Updating Cumulative Player Statistics for Player: Jean Rene Lisnard
# Updating Cumulative Player Statistics for Player: Juan Balcells
# Updating Cumulative Player Statistics for Player: Bjorn Phau
# Updating Cumulative Player Statistics for Player: David Nalbandian
# Updating Cumulative Player Statistics for Player: Guillermo Coria
# Updating Cumulative Player Statistics for Player: Jurgen Melzer
# Updating Cumulative Player Statistics for Player: Martin Lee
# Updating Cumulative Player Statistics for Player: Tommy Robredo
# Updating Cumulative Player Statistics for Player: Joachim Johansson
# Updating Cumulative Player Statistics for Player: Jarkko Nieminen
# Updating Cumulative Player Statistics for Player: Feliciano Lopez
# Updating Cumulative Player Statistics for Player: Ivo Heuberger
# Updating Cumulative Player Statistics for Player: Paul Henri Mathieu
# Updating Cumulative Player Statistics for Player: Federico Luzzi
# Updating Cumulative Player Statistics for Player: Jeff Morrison
# Updating Cumulative Player Statistics for Player: Martin Verkerk
# Updating Cumulative Player Statistics for Player: Nikolay Davydenko
# Updating Cumulative Player Statistics for Player: Jan Hernych
# Updating Cumulative Player Statistics for Player: Nicolas Mahut
# Updating Cumulative Player Statistics for Player: Luis Horna
# Updating Cumulative Player Statistics for Player: Danai Udomchoke
# Updating Cumulative Player Statistics for Player: Mario Ancic
# Updating Cumulative Player Statistics for Player: Gilles Muller
# Updating Cumulative Player Statistics for Player: Ivo Karlovic
# Updating Cumulative Player Statistics for Player: Jan Vacek
# Updating Cumulative Player Statistics for Player: Dmitry Tursunov
# Updating Cumulative Player Statistics for Player: Robby Ginepri
# Updating Cumulative Player Statistics for Player: Alex Bogomolov Jr
# Updating Cumulative Player Statistics for Player: Jose Acasuso
# Updating Cumulative Player Statistics for Player: Alexander Peya
# Updating Cumulative Player Statistics for Player: Irakli Labadze
# Updating Cumulative Player Statistics for Player: Olivier Mutis
# Updating Cumulative Player Statistics for Player: Albert Montanes
# Updating Cumulative Player Statistics for Player: Ruben Ramirez Hidalgo
# Updating Cumulative Player Statistics for Player: Marc Lopez
# Updating Cumulative Player Statistics for Player: Filippo Volandri
# Updating Cumulative Player Statistics for Player: Radek Stepanek
# Updating Cumulative Player Statistics for Player: Flavio Saretta
# Updating Cumulative Player Statistics for Player: Robin Soderling
# Updating Cumulative Player Statistics for Player: Julien Benneteau
# Updating Cumulative Player Statistics for Player: Ricardo Mello
# Updating Cumulative Player Statistics for Player: Janko Tipsarevic
# Updating Cumulative Player Statistics for Player: Yen Hsun Lu
# Updating Cumulative Player Statistics for Player: Jimmy Wang
# Updating Cumulative Player Statistics for Player: Alejandro Falla
# Updating Cumulative Player Statistics for Player: Thierry Ascione
# Updating Cumulative Player Statistics for Player: Rajeev Ram
# Updating Cumulative Player Statistics for Player: Karol Beck
# Updating Cumulative Player Statistics for Player: Brian Vahaly
# Updating Cumulative Player Statistics for Player: Rafael Nadal
# Updating Cumulative Player Statistics for Player: David Ferrer
# Updating Cumulative Player Statistics for Player: Fernando Verdasco
# Updating Cumulative Player Statistics for Player: Philipp Kohlschreiber
# Updating Cumulative Player Statistics for Player: Richard Gasquet
# Updating Cumulative Player Statistics for Player: Denis Gremelmayr
# Updating Cumulative Player Statistics for Player: Victor Hanescu
# Updating Cumulative Player Statistics for Player: Olivier Patience
# Updating Cumulative Player Statistics for Player: Frank Dancevic
# Updating Cumulative Player Statistics for Player: Wesley Moodie
# Updating Cumulative Player Statistics for Player: Igor Kunitsyn
# Updating Cumulative Player Statistics for Player: Kristof Vliegen
# Updating Cumulative Player Statistics for Player: Peter Luczak
# Updating Cumulative Player Statistics for Player: Tomas Berdych
# Updating Cumulative Player Statistics for Player: Roko Karanusic
# Updating Cumulative Player Statistics for Player: Amer Delic
# Updating Cumulative Player Statistics for Player: Oscar Hernandez
# Updating Cumulative Player Statistics for Player: Bobby Reynolds
# Updating Cumulative Player Statistics for Player: Stanislas Wawrinka
# Updating Cumulative Player Statistics for Player: Nicolas Almagro
# Updating Cumulative Player Statistics for Player: Igor Andreev
# Updating Cumulative Player Statistics for Player: Potito Starace
# Updating Cumulative Player Statistics for Player: Philipp Petzschner
# Updating Cumulative Player Statistics for Player: Simon Greul
# Updating Cumulative Player Statistics for Player: Andreas Seppi
# Updating Cumulative Player Statistics for Player: Chris Guccione
# Updating Cumulative Player Statistics for Player: Florent Serra
# Updating Cumulative Player Statistics for Player: Robin Vik
# Updating Cumulative Player Statistics for Player: Daniel Koellerer
# Updating Cumulative Player Statistics for Player: Paul Capdeville
# Updating Cumulative Player Statistics for Player: Guillermo Garcia Lopez
# Updating Cumulative Player Statistics for Player: Boris Pashanski
# Updating Cumulative Player Statistics for Player: Juan Monaco
# Updating Cumulative Player Statistics for Player: Florian Mayer
# Updating Cumulative Player Statistics for Player: Daniel Gimeno Traver
# Updating Cumulative Player Statistics for Player: Wayne Odesnik
# Updating Cumulative Player Statistics for Player: Novak Djokovic
# Updating Cumulative Player Statistics for Player: Marcos Baghdatis
# Updating Cumulative Player Statistics for Player: Gilles Simon
# Updating Cumulative Player Statistics for Player: Gael Monfils
# Updating Cumulative Player Statistics for Player: Jo Wilfried Tsonga
# Updating Cumulative Player Statistics for Player: Andreas Beck
# Updating Cumulative Player Statistics for Player: Teymuraz Gabashvili
# Updating Cumulative Player Statistics for Player: Sergiy Stakhovsky
# Updating Cumulative Player Statistics for Player: Ivan Navarro
# Updating Cumulative Player Statistics for Player: Ivo Minar
# Updating Cumulative Player Statistics for Player: Frederico Gil
# Updating Cumulative Player Statistics for Player: Ivan Dodig
# Updating Cumulative Player Statistics for Player: Ryan Harrison
# Updating Cumulative Player Statistics for Player: Jerzy Janowicz
# Updating Cumulative Player Statistics for Player: Evgeny Donskoy
# Updating Cumulative Player Statistics for Player: Vasek Pospisil
# Updating Cumulative Player Statistics for Player: Illya Marchenko
# Updating Cumulative Player Statistics for Player: Marsel Ilhan
# Updating Cumulative Player Statistics for Player: Andrey Kuznetsov
# Updating Cumulative Player Statistics for Player: Horacio Zeballos
# Updating Cumulative Player Statistics for Player: Federico Delbonis
# Updating Cumulative Player Statistics for Player: Roberto Bautista Agut
# Updating Cumulative Player Statistics for Player: Bernard Tomic
# Updating Cumulative Player Statistics for Player: Guillaume Rufin
# Updating Cumulative Player Statistics for Player: Milos Raonic
# Updating Cumulative Player Statistics for Player: Dusan Lajovic
# Updating Cumulative Player Statistics for Player: Benoit Paire
# Updating Cumulative Player Statistics for Player: Albert Ramos
# Updating Cumulative Player Statistics for Player: Jack Sock
# Updating Cumulative Player Statistics for Player: Marinko Matosevic
# Updating Cumulative Player Statistics for Player: Matthew Ebden
# Updating Cumulative Player Statistics for Player: Joao Souza
# Updating Cumulative Player Statistics for Player: Steve Johnson
# Updating Cumulative Player Statistics for Player: Denis Kudla
# Updating Cumulative Player Statistics for Player: Aljaz Bedene
# Updating Cumulative Player Statistics for Player: David Goffin
# Updating Cumulative Player Statistics for Player: Kenny De Schepper
# Updating Cumulative Player Statistics for Player: Dominic Thiem
# Updating Cumulative Player Statistics for Player: Pablo Carreno Busta
# Updating Cumulative Player Statistics for Player: James Duckworth
# Updating Cumulative Player Statistics for Player: Diego Sebastian Schwartzman
# Updating Cumulative Player Statistics for Player: Jan Lennard Struff
# Updating Cumulative Player Statistics for Player: Alexander Zverev
# Updating Cumulative Player Statistics for Player: Jiri Vesely
# Updating Cumulative Player Statistics for Player: Nick Kyrgios
# Updating Cumulative Player Statistics for Player: Alejandro Gonzalez
# Updating Cumulative Player Statistics for Player: Borna Coric
# Player Statistics Generation Runtime = 10527.648466587067 seconds
# Number of valid players with 40 matches of initial match data = 278

# %%
#Add Heights(cm) for the missing players
PlayerStats.loc[105311, 'Height(cm)'] = 185
PlayerStats.loc[105138, 'Height(cm)'] = 183
PlayerStats.loc[105807, 'Height(cm)'] = 188
PlayerStats.loc[106233, 'Height(cm)'] = 185
PlayerStats.loc[105526, 'Height(cm)'] = 196
PlayerStats.loc[106210, 'Height(cm)'] = 198
PlayerStats.loc[106401, 'Height(cm)'] = 193
PlayerStats.loc[106432, 'Height(cm)'] = 185

# %%
#Use query function to return smaller subsets
q1 = PlayerStats[(PlayerStats['Overall Win%'] >= 0) & (PlayerStats['Height(cm)'] != 200)]

print(len(q1.index))
print(len(PlayerStats.index))
q1
# Out:
# 278
# 1994
#        PlayerID                        PName Height(cm) Matches Played  \
# 102776   102776                  Andrew Ilie        180             40
# 103602   103602            Fernando Gonzalez        183             40
# 102821   102821                 Cecil Mamiit        173             40
# 103387   103387          Paradorn Srichaphan        185             40
# 102925   102925             Justin Gimelstob        196             40
# 103181   103181                   Jiri Vanek        185             40
# 102834   102834               Paul Goldstein        178             40
# 103454   103454                Nicolas Massu        183             40
# 103188   103188              Michael Russell        173             40
# 102880   102880               Alexander Popp        201             40
# 102987   102987                     Andre Sa        185             40
# 103082   103082              Markus Hantschk        188             40
# 103598   103598               Xavier Malisse        185             40
# 102887   102887                Ramon Delgado        185             40
# 102998   102998          Jan Michael Gambill        190             40
# 103420   103420                Michal Tabara        175             40
# 102911   102911             Andrei Stoliarov        178             40
# 103240   103240                    Kevin Kim        180             40
# 102905   102905                Stefan Koubek        175             40
# 102338   102338           Yevgeny Kafelnikov        190             40
# 102446   102446              Andrei Medvedev        193             40
# 102563   102563             Thomas Johansson        180             40
# 103498   103498                  Marat Safin        193             40
# 102271   102271                 Hicham Arazi        175             40
# 103151   103151             Mariano Zabaleta        183             40
# 102450   102450                   Tim Henman        185             40
# 102783   102783            Rainer Schuettler        180             40
# 102259   102259               Jerome Golmard        188             40
# 103507   103507          Juan Carlos Ferrero        183             40
# 103096   103096               Arnaud Clement        173             40
# ...         ...                          ...        ...            ...
# 104947   104947                 Marsel Ilhan        190             40
# 105723   105723             Andrey Kuznetsov        185             40
# 104547   104547             Horacio Zeballos        188             40
# 105643   105643            Federico Delbonis        190             40
# 105138   105138        Roberto Bautista Agut        183             40
# 106071   106071                Bernard Tomic        193             40
# 105558   105558              Guillaume Rufin        188             40
# 105683   105683                 Milos Raonic        196             40
# 105583   105583                Dusan Lajovic        180             40
# 105332   105332                 Benoit Paire        196             40
# 105077   105077                 Albert Ramos        188             40
# 106058   106058                    Jack Sock        185             40
# 104594   104594            Marinko Matosevic        194             40
# 105051   105051                Matthew Ebden        188             40
# 105154   105154                   Joao Souza        193             40
# 105449   105449                Steve Johnson        188             40
# 106045   106045                  Denis Kudla        180             40
# 105379   105379                 Aljaz Bedene        181             40
# 105676   105676                 David Goffin        163             40
# 104932   104932            Kenny De Schepper        203             40
# 106233   106233                Dominic Thiem        185             40
# 105807   105807          Pablo Carreno Busta        188             40
# 105902   105902              James Duckworth        183             40
# 106043   106043  Diego Sebastian Schwartzman        NaN             40
# 105526   105526           Jan Lennard Struff        196             40
# 100644   100644             Alexander Zverev        NaN             40
# 106210   106210                  Jiri Vesely        198             40
# 106401   106401                 Nick Kyrgios        193             40
# 105292   105292           Alejandro Gonzalez        NaN             40
# 106432   106432                  Borna Coric        185             40
#
#        Overall Win% Top 100 Win % Top 30 Win % First Serve %  \
# 102776         0.45       0.37931     0.272727      0.519141
# 103602          0.5          0.36     0.285714      0.585753
# 102821         0.35      0.285714    0.0833333       0.56159
# 103387        0.325          0.16     0.166667      0.547278
# 102925        0.425      0.391304     0.272727      0.583462
# 103181        0.375          0.28         0.25      0.547442
# 102834        0.475          0.36     0.111111        0.6318
# 103454        0.525           0.4        0.125      0.547837
# 103188         0.25      0.137931            0      0.683744
# 102880        0.425      0.357143     0.222222      0.605206
# 102987        0.375         0.375          0.4      0.601039
# 103082        0.475      0.421053            0      0.570184
# 103598          0.6           0.5     0.384615      0.581118
# 102821   102821         Cecil Mamiit        173             40         0.35
# 103387   103387  Paradorn Srichaphan        185             40        0.325
# 102925   102925     Justin Gimelstob        196             40        0.425
# 103181   103181           Jiri Vanek        185             40        0.375
# 102834   102834       Paul Goldstein        178             40        0.475
# 103454   103454        Nicolas Massu        183             40        0.525
# 103188   103188      Michael Russell        173             40         0.25
# 102880   102880       Alexander Popp        201             40        0.425
# 102987   102987             Andre Sa        185             40        0.375
# 103082   103082      Markus Hantschk        188             40        0.475
# 103598   103598       Xavier Malisse        185             40          0.6
# 102887   102887        Ramon Delgado        185             40        0.375
# 102998   102998  Jan Michael Gambill        190             40          0.6
# 103420   103420        Michal Tabara        175             40        0.475
# 102911   102911     Andrei Stoliarov        178             40         0.45
# 103240   103240            Kevin Kim        180             40        0.425
# 102905   102905        Stefan Koubek        175             40        0.525
# 102338   102338   Yevgeny Kafelnikov        190             40         0.75
#
#        Top 100 Win % Top 30 Win % First Serve % First Serve Win %  BPSave %  \
# 102776       0.37931     0.272727      0.519141          0.714681   0.61442
# 103602          0.36     0.285714      0.585753          0.711104  0.608541
# 102821      0.285714    0.0833333       0.56159          0.671882  0.588889
# 103387          0.16     0.166667      0.547278          0.681467  0.581538
# 102925      0.391304     0.272727      0.583462          0.735052  0.585761
# 103181          0.28         0.25      0.547442          0.697113  0.599469
# 102834          0.36     0.111111        0.6318          0.644716  0.590769
# 103454           0.4        0.125      0.547837          0.723821  0.581197
# 103188      0.137931            0      0.683744          0.625503  0.554622
# 102880      0.357143     0.222222      0.605206          0.679493  0.600559
# 102987         0.375          0.4      0.601039          0.647759    0.5625
# 103082      0.421053            0      0.570184          0.677385  0.626113
# 103598           0.5     0.384615      0.581118          0.725631  0.610909
# 102887      0.366667            0      0.604302          0.666575  0.501767
# 102998      0.566667     0.571429      0.552987           0.78236  0.674107
# 103420      0.304348     0.142857      0.536839          0.667198  0.566154
# 102911      0.346154     0.285714      0.468847          0.701175  0.569182
# 103240      0.347826          0.1       0.58777          0.696873  0.541045
# 102905           0.5          0.1      0.595983          0.680214  0.537037
# 102338       0.71875     0.636364       0.55528          0.749184  0.662745
#
#         BPConv % Aces/Match DF/Match Future Top 30
# 102776  0.346154       6.15    3.525         False
# 103602  0.421642        6.4     7.35          True
# 102821  0.374582       3.65     2.85         False
# 103387  0.383399        5.3    4.525          True
# 102925  0.349481        7.9      4.8         False
# 103181  0.392523        6.1     3.15         False
# 102834  0.395137      2.325    2.275         False
# 103454  0.452915        4.4    2.975          True
# 103188  0.384615      2.475      3.3         False
# 102880  0.402516       4.35    5.175         False
# 102987   0.40678        2.5    2.575         False
# 103082     0.425        3.9      2.4         False
# 103598  0.407295      6.075      2.5          True
# 102887   0.37276       5.95      2.7         False
# 102998  0.381679     12.275    3.675          True
# 103420  0.437908      2.875      3.5         False
# 102911  0.359621      4.825     4.75         False
# 103240  0.378676      5.325    2.725         False
# 102905  0.417266      4.475    3.475          True
# 102338  0.448171      5.875        4          True

# %%
#Export the extracted feature set to a csv file
ATPplayerFeatures.to_csv("ATPPlayerFeatures40.csv", index = False)
